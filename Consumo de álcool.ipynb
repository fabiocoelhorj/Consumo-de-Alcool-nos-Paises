# %% [markdown]
# ## Consumo de álcool
# ### Taxa de suicídio, renda, emprego e taxa urbana
#
# Fonte: https://www.kaggle.com/

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Suporte/Desktop/archive/gapminder_alcohol.csv')

# %%
df.head()
# Out:
#        country  alcconsumption  incomeperperson  suicideper100th  employrate  \
# 0  Afghanistan            0.03              NaN         6.684385   55.700001
# 1      Albania            7.29      1914.996551         7.699330   51.400002
# 2      Algeria            0.69      2231.993335         4.848770   50.500000
# 3      Andorra           10.17     21943.339900         5.362179         NaN
# 4       Angola            5.57      1381.004268        14.554677   75.699997
#
#    urbanrate
# 0      24.04
# 1      46.72
# 2      65.22
# 3      88.92
# 4      56.70

# %% [markdown]
# ### Tradução das colunas

# %%
df.columns = ['País', 'Consumo de Álcool', 'Renda por Pessoa', 'Taxa de Suicídio', 'Taxa de Emprego', 'Taxa urbana']

# %%
df.head()
# Out:
#           País  Consumo de Álcool  Renda por Pessoa  Taxa de Suicídio  \
# 0  Afghanistan               0.03               NaN          6.684385
# 1      Albania               7.29       1914.996551          7.699330
# 2      Algeria               0.69       2231.993335          4.848770
# 3      Andorra              10.17      21943.339900          5.362179
# 4       Angola               5.57       1381.004268         14.554677
#
#    Taxa de Emprego  Taxa urbana
# 0        55.700001        24.04
# 1        51.400002        46.72
# 2        50.500000        65.22
# 3              NaN        88.92
# 4        75.699997        56.70

# %% [markdown]
# ### Os 10 Países com Menores Consumos de Álcool

# %%
consum = df.groupby('Consumo de Álcool').agg({'País' : 'min'})

# %%
consum.head(10)
# Out:
#                           País
# Consumo de Álcool
# 0.03               Afghanistan
# 0.05                  Pakistan
# 0.10                    Kuwait
# 0.11                Mauritania
# 0.17                Bangladesh
# 0.20               Yemen, Rep.
# 0.28                   Comoros
# 0.32                     Egypt
# 0.34                     Niger
# 0.47                      Iraq

# %% [markdown]
# ### Os 6 Países com Maiores Consumos de Álcool

# %%
df.nlargest(6, 'Consumo de Álcool')
# Out:
#             País  Consumo de Álcool  Renda por Pessoa  Taxa de Suicídio  \
# 126      Moldova              23.01        595.874534          15.53849
# 100  Korea, Rep.              19.15      16372.499780          22.40456
# 16       Belarus              18.85       2737.670379          26.87469
# 200      Ukraine              17.47       1036.830725          18.95457
# 59       Estonia              17.24       6238.537506          16.95924
# 49    Czech Rep.              16.47       7381.312751          12.36798
#
#      Taxa de Emprego  Taxa urbana
# 126        44.299999        41.76
# 100        58.900002        81.46
# 16         53.400002        73.46
# 200        54.400002        67.98
# 59         56.500000        69.46
# 49         56.000000        73.50

# %% [markdown]
# ### Os 7 Países com Maiores Taxas de Suicídio

# %%
df.nlargest(7, 'Taxa de Suicídio')
# Out:
#           País  Consumo de Álcool  Renda por Pessoa  Taxa de Suicídio  \
# 80      Guyana               8.70       1200.652075         35.752872
# 110  Lithuania              16.30       5332.238591         33.341860
# 177    Somalia               0.50               NaN         29.864164
# 180  Sri Lanka               0.81       1295.742686         28.104046
# 159     Russia              16.23       2923.144355         27.874160
# 16     Belarus              18.85       2737.670379         26.874690
# 103       Laos               6.99        554.879840         26.219198
#
#      Taxa de Emprego  Taxa urbana
# 80         58.900002        28.38
# 110        53.099998        66.96
# 177        66.000000        36.52
# 180        55.099998        15.10
# 159        58.799999        72.84
# 16         53.400002        73.46
# 103        78.199997        30.88

# %% [markdown]
# ### Apagando os dados em branco (Nan)

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Contando os dados da Tabela (Linhas e Colunas)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162 entries, 1 to 212
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   País               162 non-null    object
#  1   Consumo de Álcool  162 non-null    float64
#  2   Renda por Pessoa   162 non-null    float64
#  3   Taxa de Suicídio   162 non-null    float64
#  4   Taxa de Emprego    162 non-null    float64
#  5   Taxa urbana        162 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 8.9+ KB

# %%
a1 = df['Taxa de Suicídio'].{0!s}'.format
# Out:
#   File "<ipython-input-45-4a04783d4222>", line 1
#     a1 = df['Taxa de Suicídio'].{0!s}'.format
#                                 ^
# SyntaxError: invalid syntax

# %%
df.replace('Afghanistan', 'Afeganistão')
# Out:
#             País  Consumo de Álcool  Renda por Pessoa  Taxa de Suicídio  \
# 1        Albania               7.29       1914.996551          7.699330
# 2        Algeria               0.69       2231.993335          4.848770
# 4         Angola               5.57       1381.004268         14.554677
# 6      Argentina               9.35      10749.419240          7.765584
# 7        Armenia              13.66       1326.741757          3.741588
# ..           ...                ...               ...               ...
# 207    Venezuela               7.60       5528.363114          4.119620
# 208      Vietnam               3.91        722.807559         11.653322
# 210  Yemen, Rep.               0.20        610.357367          6.265789
# 211       Zambia               3.56        432.226337         12.019036
# 212     Zimbabwe               4.96        320.771890         13.905267
#
#      Taxa de Emprego  Taxa urbana
# 1          51.400002        46.72
# ...

# %%
df.head()
# Out:
#         País  Consumo de Álcool  Renda por Pessoa  Taxa de Suicídio  \
# 1    Albania               7.29       1914.996551          7.699330
# 2    Algeria               0.69       2231.993335          4.848770
# 4     Angola               5.57       1381.004268         14.554677
# 6  Argentina               9.35      10749.419240          7.765584
# 7    Armenia              13.66       1326.741757          3.741588
#
#    Taxa de Emprego  Taxa urbana
# 1        51.400002        46.72
# 2        50.500000        65.22
# 4        75.699997        56.70
# 6        58.400002        92.00
# 7        40.099998        63.86

# %% [markdown]
# ### Arredondando as casas decimais dos valores da tabela

# %%
 df.round(2)
# Out:
#             País  Consumo de Álcool  Renda por Pessoa  Taxa de Suicídio  \
# 1        Albania               7.29           1915.00              7.70
# 2        Algeria               0.69           2231.99              4.85
# 4         Angola               5.57           1381.00             14.55
# 6      Argentina               9.35          10749.42              7.77
# 7        Armenia              13.66           1326.74              3.74
# ..           ...                ...               ...               ...
# 207    Venezuela               7.60           5528.36              4.12
# 208      Vietnam               3.91            722.81             11.65
# 210  Yemen, Rep.               0.20            610.36              6.27
# 211       Zambia               3.56            432.23             12.02
# 212     Zimbabwe               4.96            320.77             13.91
#
#      Taxa de Emprego  Taxa urbana
# 1               51.4        46.72
# ...

# %% [markdown]
# ### Localizando os índices das linhas 20 até a 40

# %%
df.iloc[20:40]
# Out:
#                     País  Consumo de Álcool  Renda por Pessoa  \
# 25                Brazil              10.08       4699.411262
# 26                Brunei               1.86      17092.460000
# 27              Bulgaria              11.40       2549.558474
# 28          Burkina Faso               7.32        276.200413
# 29               Burundi               9.65        115.305996
# 30              Cambodia               4.71        557.947513
# 31              Cameroon               7.90        713.639303
# 32                Canada              10.20      25575.352620
# 33            Cape Verde               4.98       1959.844472
# 35  Central African Rep.               3.17        239.518749
# 36                  Chad               4.39        275.884287
# 37                 Chile               8.81       6334.105194
# 38                 China               5.56       2425.471293
# 39              Colombia               6.59       3233.423780
# ...

# %% [markdown]
# ### Filtrar somente os países e consumos de álcool

# %%
df[['Consumo de Álcool', 'País']].groupby(['País']).sum()
# Out:
#              Consumo de Álcool
# País
# Albania                   7.29
# Algeria                   0.69
# Angola                    5.57
# Argentina                 9.35
# Armenia                  13.66
# ...                        ...
# Venezuela                 7.60
# Vietnam                   3.91
# Yemen, Rep.               0.20
# Zambia                    3.56
# Zimbabwe                  4.96
#
# [162 rows x 1 columns]
